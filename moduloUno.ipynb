# %% [markdown]
# # Oficial superior> "¿Puedes construir un programa que me muestre la fecha? La computadora la nave no venía con mucho en términos de programas de utilidad, por lo que necesitamos crear los que necesitamos. ¿Puedo confiar en ti con esto?"

# %%
from datetime import date

print("Today's date is: ")
# Out:
# Today's date is:

# %%
from datetime import date

print("Hoy es el día " + str(date.today()))
# Out:
# Hoy es el día 2022-02-10

# %% [markdown]
# # El oficial superior> "Necesito una cosa más: un programa de conversión entre parsecs y años luz. Tener un programa de este tipo podría ser realmente útil en el puente para trazar nuestro curso".

# %% [markdown]
# # 1 parsec es 3.26156 años luz. Utiliza el operador de multiplicación.

# %%
parsec = 11

lightyears = 0

print(str(parsec) + " parsec, is " + str(lightyears) + " lightyears")
# Out:
# 11 parsec, is 0 lightyears

# %%
parsec = 11
lightyears = 3.26156 * parsec

print(str(parsec) + " parsec, is " + str(lightyears) + " lightyears")
# Out:
# 11 parsec, is 35.877159999999996 lightyears
